# %%
from metricsFunctions import optimalTau, calc_metrics, sgmmResults, metrics_cluster
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from supervisedGmm import  SupervisedGMM

# %%
# %load_ext autoreload
# %autoreload 2

# %%
sparcs = pd.read_csv("sparcs25%Preg_DeHos_Outflow_NYC_only.csv") 



d_newborn_tr, d_newborn_te = train_test_split(sparcs, test_size=0.2, random_state = 1512)

print(d_newborn_tr.shape[0], d_newborn_tr.shape[1])
# Out:
# 59819 170

# %%
#VALIDATION ON CLUSTERS
#RUN VALIDATION ON NUMBER OF CLUSTERS BASED ON AUC
import time

train, val = train_test_split(d_newborn_tr, test_size = 0.2, random_state = 1512)
y_train, y_val = train.iloc[:,-1], val.iloc[:,-1]

print( train.shape, val.shape )

#SET SGMM PARAMETERS
#regularization parameters
C = [0.01, 0.1, 1, 5, 10, 15, 20, 50]
max_iter2 = 30

train_np = train.iloc[:,0:-1].values
val_np = val.iloc[:,0:-1].values

y_train_np = y_train.values
y_val_np = y_val.values

test_re = []
train_re = []

start = time.time()

#test clusters 0-12
for i in range(2,25):
    print("\n\n\nTRAINING WITH {} CLUSTERS".format(i))
    model = SupervisedGMM(C = C, max_iter2 = max_iter2, n_clusters = i, verbose = 0)
    model = model.fit(Xtrain = train_np, ytrain = y_train_np)
    probTrain = model.predict_proba( train_np )
    probTest = model.predict_proba( val_np )
    results = sgmmResults( model, probTest.copy(), probTrain.copy(), y_val_np.copy(), y_train_np.copy(), tau = None,
                mode = 0)
    testmetrics = results['testMet']
    trainMetrics = results[ 'trainMet']
    test_re.append( testmetrics )
    train_re.append( trainMetrics )
    
end = time.time() - start
print("time elapsed: {}".format( end ))
# Out:
# (47855, 170) (11964, 170)
#
#
#
# TRAINING WITH 2 CLUSTERS
# GMM iteration: 0, error: 7.120047274384408e-05
#
#
#
# TRAINING WITH 3 CLUSTERS
# GMM iteration: 0, error: 0.061385131385540484
# GMM iteration: 1, error: 0.013113661502444762
# GMM iteration: 2, error: 0.004775102930084895
# GMM iteration: 3, error: 0.31054515325338233
# GMM iteration: 4, error: 0.11050896161280412
# GMM iteration: 5, error: 0.02530467538565311
# GMM iteration: 6, error: 0.00573735726490275
# GMM iteration: 7, error: 0.0011486272172379303
# GMM iteration: 8, error: 0.00023060710608076578
#
#
#
# TRAINING WITH 4 CLUSTERS
# GMM iteration: 0, error: 0.008183314097074481
# GMM iteration: 1, error: 0.0018949892853784025
# GMM iteration: 2, error: 0.0005672160943447742
#
#
#
# TRAINING WITH 5 CLUSTERS
# GMM iteration: 0, error: 0.011798859370406256
# GMM iteration: 1, error: 0.018141137813643553
# GMM iteration: 2, error: 0.004611411187356476
# GMM iteration: 3, error: 0.0010206823948492284
# GMM iteration: 4, error: 0.00034088637067089604
#
#
#
# TRAINING WITH 6 CLUSTERS
# GMM iteration: 0, error: 0.020389353015089453
# GMM iteration: 1, error: 0.004505384906124529
# GMM iteration: 2, error: 0.0009667126343463192
#
#
#
# TRAINING WITH 7 CLUSTERS
# GMM iteration: 0, error: 0.07201050371513634
# GMM iteration: 1, error: 0.04424141585967594
# GMM iteration: 2, error: 0.032725321326067015
# GMM iteration: 3, error: 0.008702259239000908
# GMM iteration: 4, error: 0.0020412022966266336
# GMM iteration: 5, error: 0.0004798616458263603
#
#
#
# TRAINING WITH 8 CLUSTERS
# GMM iteration: 0, error: 0.009940434593682655
# GMM iteration: 1, error: 0.007954611313411273
# GMM iteration: 2, error: 0.03914506695866471
# GMM iteration: 3, error: 0.01584785482896005
# GMM iteration: 4, error: 0.005024652614123965
# GMM iteration: 5, error: 0.04202806712890937
# GMM iteration: 6, error: 0.0496728835655759
# GMM iteration: 7, error: 0.010936679300902924
# GMM iteration: 8, error: 0.0024941112691737994
# GMM iteration: 9, error: 0.001158607122170587
# GMM iteration: 10, error: 0.0011535157002395807
# GMM iteration: 11, error: 0.0003944819476436245
#
#
#
# TRAINING WITH 9 CLUSTERS
# GMM iteration: 0, error: 0.05904195632005178
# GMM iteration: 1, error: 0.03762496633759828
# GMM iteration: 2, error: 0.01014376717687746
# GMM iteration: 3, error: 0.0032097733682676776
# GMM iteration: 4, error: 0.0012484892167916274
# GMM iteration: 5, error: 0.0005370760938410386
#
#
#
# TRAINING WITH 10 CLUSTERS
# GMM iteration: 0, error: 0.03499032003915121
# GMM iteration: 1, error: 0.01588814022376369
# GMM iteration: 2, error: 0.004328299749007977
# GMM iteration: 3, error: 0.0026497591513656286
# GMM iteration: 4, error: 0.0482408748122703
# GMM iteration: 5, error: 0.03742108493689005
# GMM iteration: 6, error: 0.009567382684800061
# GMM iteration: 7, error: 0.0025544632288133076
# GMM iteration: 8, error: 0.0006861833194323809
#
#
#
# TRAINING WITH 11 CLUSTERS
# GMM iteration: 0, error: 0.040764586900233137
# GMM iteration: 1, error: 0.019269493251857
# GMM iteration: 2, error: 0.005681391516954284
# GMM iteration: 3, error: 0.00249537306420928
# GMM iteration: 4, error: 0.0009688396624490167
#
#
#
# TRAINING WITH 12 CLUSTERS
# GMM iteration: 0, error: 0.008901028995509685
# GMM iteration: 1, error: 0.0018865161299803236
# GMM iteration: 2, error: 0.0004817356791104891
#
#
#
# TRAINING WITH 13 CLUSTERS
# GMM iteration: 0, error: 0.04328037637429239
# GMM iteration: 1, error: 0.016922670322015755
# GMM iteration: 2, error: 0.018245541385764532
# GMM iteration: 3, error: 0.011131763712819355
# GMM iteration: 4, error: 0.0069157005353239565
# GMM iteration: 5, error: 0.007411141580802175
# GMM iteration: 6, error: 0.005663691402570674
# GMM iteration: 7, error: 0.002695460716817622
# GMM iteration: 8, error: 0.0020501545710811583
# GMM iteration: 9, error: 0.004914405233428719
# GMM iteration: 10, error: 0.0019106911042313184
# GMM iteration: 11, error: 0.000538275835598563
#
#
#
# TRAINING WITH 14 CLUSTERS
# GMM iteration: 0, error: 0.02824012913601882
# GMM iteration: 1, error: 0.013682192261483648
# GMM iteration: 2, error: 0.008000219202153396
# GMM iteration: 3, error: 0.003466583788615774
# GMM iteration: 4, error: 0.005889606638068402
# GMM iteration: 5, error: 0.00862330328641357
# GMM iteration: 6, error: 0.016490915415004314
# GMM iteration: 7, error: 0.026088893859693017
# GMM iteration: 8, error: 0.01469841695745019
# GMM iteration: 9, error: 0.0038401296259819046
# GMM iteration: 10, error: 0.001480821698249188
# GMM iteration: 11, error: 0.00044458450789369475
#
#
#
# TRAINING WITH 15 CLUSTERS
# GMM iteration: 0, error: 0.01723939731691165
# GMM iteration: 1, error: 0.029229624645214013
# GMM iteration: 2, error: 0.03817175722958417
# GMM iteration: 3, error: 0.030044299138234337
# GMM iteration: 4, error: 0.008561840653875833
# GMM iteration: 5, error: 0.0037727089001278577
# GMM iteration: 6, error: 0.002126657876936597
# GMM iteration: 7, error: 0.0012030140623346102
# GMM iteration: 8, error: 0.0004290859541614409
#
#
#
# TRAINING WITH 16 CLUSTERS
# GMM iteration: 0, error: 0.031481823413481214
# GMM iteration: 1, error: 0.017700388263194623
# GMM iteration: 2, error: 0.010192723043819926
# GMM iteration: 3, error: 0.015406963133433212
# GMM iteration: 4, error: 0.007763627982951844
# GMM iteration: 5, error: 0.006700622175771476
# GMM iteration: 6, error: 0.0036608804711002973
# GMM iteration: 7, error: 0.0028532811069313544
# GMM iteration: 8, error: 0.0007988639134267116
#
#
#
# TRAINING WITH 17 CLUSTERS
# GMM iteration: 0, error: 0.018542612756810243
# GMM iteration: 1, error: 0.016681765432860547
# GMM iteration: 2, error: 0.011585495627383586
# GMM iteration: 3, error: 0.005939472062377066
# GMM iteration: 4, error: 0.002688216946254708
# GMM iteration: 5, error: 0.003038164020709163
# GMM iteration: 6, error: 0.001875294877870623
# GMM iteration: 7, error: 0.0016537318300298574
# GMM iteration: 8, error: 0.0007243658860332583
#
#
#
# TRAINING WITH 18 CLUSTERS
# GMM iteration: 0, error: 0.019827141168862885
# GMM iteration: 1, error: 0.005671756927106698
# GMM iteration: 2, error: 0.005019619534680894
# GMM iteration: 3, error: 0.00962010975588582
# GMM iteration: 4, error: 0.005464437370485792
# GMM iteration: 5, error: 0.011058386847151271
# GMM iteration: 6, error: 0.02357012612147454
# GMM iteration: 7, error: 0.01777248170320991
# GMM iteration: 8, error: 0.014029947476353164
# GMM iteration: 9, error: 0.016665261263653867
# GMM iteration: 10, error: 0.013946187051900276
# GMM iteration: 11, error: 0.013472896079846508
# GMM iteration: 12, error: 0.014554342276192902
# GMM iteration: 13, error: 0.0030901085430664137
# GMM iteration: 14, error: 0.0008886936831652895
#
#
#
# TRAINING WITH 19 CLUSTERS
# GMM iteration: 0, error: 0.013318439433370816
# GMM iteration: 1, error: 0.006864355201564121
# GMM iteration: 2, error: 0.006315291666502029
# GMM iteration: 3, error: 0.009733444774320664
# GMM iteration: 4, error: 0.008989549178921702
# GMM iteration: 5, error: 0.0038606733668292894
# GMM iteration: 6, error: 0.0019283745251689225
# GMM iteration: 7, error: 0.001326021262649076
# GMM iteration: 8, error: 0.0007308782312006263
#
#
#
# TRAINING WITH 20 CLUSTERS
# GMM iteration: 0, error: 0.02016206238510796
# GMM iteration: 1, error: 0.0291353779802458
# GMM iteration: 2, error: 0.011902475136416709
# GMM iteration: 3, error: 0.003396021890118489
# GMM iteration: 4, error: 0.002695336448941528
# GMM iteration: 5, error: 0.003027198631249848
# GMM iteration: 6, error: 0.0024291530647948616
# GMM iteration: 7, error: 0.001083958315920069
# GMM iteration: 8, error: 0.0005170512514136849
#
#
#
# TRAINING WITH 21 CLUSTERS
# GMM iteration: 0, error: 0.030772053598452084
# GMM iteration: 1, error: 0.01883934811537313
# GMM iteration: 2, error: 0.018834442486092555
# GMM iteration: 3, error: 0.00785796433784244
# GMM iteration: 4, error: 0.0035886349304810076
# GMM iteration: 5, error: 0.001897694843295559
# GMM iteration: 6, error: 0.0012695913964781242
# GMM iteration: 7, error: 0.00093425493251777
#
#
#
# TRAINING WITH 22 CLUSTERS
# GMM iteration: 0, error: 0.02978350579058102
# GMM iteration: 1, error: 0.02168589204209248
# GMM iteration: 2, error: 0.011897861002176166
# GMM iteration: 3, error: 0.010345302629454834
# GMM iteration: 4, error: 0.004805596698336058
# GMM iteration: 5, error: 0.0026009998859580245
# GMM iteration: 6, error: 0.002127651676802646
# GMM iteration: 7, error: 0.002084705255409076
# GMM iteration: 8, error: 0.0008478881605308732
#
#
#
# TRAINING WITH 23 CLUSTERS
# GMM iteration: 0, error: 0.010406089983530754
# GMM iteration: 1, error: 0.0037402539274977416
# GMM iteration: 2, error: 0.0033679756084417168
# GMM iteration: 3, error: 0.00428373846806914
# GMM iteration: 4, error: 0.014796794335860116
# GMM iteration: 5, error: 0.01603976809886385
# GMM iteration: 6, error: 0.012473011825014207
# GMM iteration: 7, error: 0.013468160117033261
# GMM iteration: 8, error: 0.00829548853432927
# GMM iteration: 9, error: 0.005156604420808781
# GMM iteration: 10, error: 0.003096473092496363
# GMM iteration: 11, error: 0.0014605249113218595
# GMM iteration: 12, error: 0.0006290862166686136
#
#
#
# TRAINING WITH 24 CLUSTERS
# GMM iteration: 0, error: 0.012690395663158329
# GMM iteration: 1, error: 0.005832899525882786
# GMM iteration: 2, error: 0.00232456834317235
# GMM iteration: 3, error: 0.001672786494047833
# GMM iteration: 4, error: 0.0016937261876059065
# GMM iteration: 5, error: 0.0012856754091999734
# GMM iteration: 6, error: 0.0025563742893334102

# %%
#PICK THE CLUSTERS
columns = test_re[0].columns
pdi = pd.DataFrame(np.zeros(shape = [len(test_re), test_re[0].shape[1]]), columns = columns)
pdi_tr = pd.DataFrame(np.zeros(shape = [len(train_re), train_re[0].shape[1]]), columns = columns)

for i, panda in enumerate(test_re):
     pdi.iloc[i,:] = panda.iloc[0,:]
        
for i, panda in enumerate(train_re):
     pdi_tr.iloc[i,:] = panda.iloc[0,:]

pdi.round(6)
#BASED ON THAT WE PICK 9 CLUSTERS

# %%
pdi_tr.round(6)

# %%
#TRAIN THE MODEL WITH 9 CLUSTERS
d_newborn_tr, d_newborn_te = train_test_split(sparcs, test_size=0.2, random_state = 1512)
Xtrain, Xtest = d_newborn_tr.iloc[:,0:-1].values, d_newborn_te.iloc[:,0:-1].values
ytrain, ytest = d_newborn_tr.iloc[:,-1].values.astype(int), d_newborn_te.iloc[:,-1].values.astype(int)

C = [0.01, 0.1, 1, 5, 10, 15, 20, 50]
max_iter2 = 30
n_clusters = 9

model = SupervisedGMM(C = C, max_iter2 = max_iter2, n_clusters = n_clusters, verbose = 0)
model = model.fit(Xtrain = Xtrain, ytrain = ytrain)

# %%
#TAKE THE STATISTICS OF THE MODEL
#take probabilities of test and train
probTrain = model.predict_proba( Xtrain )
probTest = model.predict_proba( Xtest )

#take the results
results_last = sgmmResults( model, probTest.copy(), probTrain.copy(), ytest, ytrain, tau = None,
                mode = 0)

train_metrics = results["trainMet"]
test_metrics = results["testMet"]

# %%
train_metrics.round(3)

# %% [markdown]
# OVERALL METRICS ON TEST DATA WITH 9 CLUSTERS

# %%
test_metrics.round(3)

# %% [markdown]
# PER CLUSTER STATISTICS

# %%
#get memberships and labels
memb_train = model.predict_GMMS(Xtrain)
memb_test = model.predict_GMMS(Xtest)

#get hard labels
testlabels = np.argmax(memb_test, axis = 1)
trainlabels = np.argmax(memb_train, axis = 1)

#get logistic regression per cluster models
per_cluster_regressions = model.LogRegr

#het the per cluster metrics
clust_Train, clust_Test = metrics_cluster(models = per_cluster_regressions, ytrain = ytrain, ytest = ytest,
                                         testlabels = testlabels, trainlabels = trainlabels, Xtrain = Xtrain,
                                          Xtest = Xtest)

# %%
#PRINT CLUSTER TEST
print("PER CLUSTER METRICS FOR TEST DATA\n")
print(clust_Test)
print("\n\n\nPER CLUSTER METRICS FOR TRAINING DATA\n")
print(clust_Train)

# %%
# just change the order of labels so that cost for each cluster goes from low to high

Labels = np.append(trainlabels, testlabels)

target= pd.DataFrame(np.append(ytrain, ytest,axis=0),columns=['Target'])
cadre = pd.DataFrame(Labels,columns=['Cadre'])

target['Cadre']= cadre['Cadre']

highcostratio = np.array([])
clustpop = np.array([])

for i in range(n_clusters):
    pop = target[target['Cadre']==i]['Target'].shape[0]
    clustpop = np.append(clustpop,pop)
    ratio = np.count_nonzero(target[target['Cadre']==i]['Target'].values)*1.0/pop
    highcostratio= np.append(highcostratio,ratio)
    
x = np.arange(n_clusters)
b=sns.lineplot(x=x,
               y=sorted(highcostratio))
plt.xticks(x,x)
#b.set_xlabel("X Label",fontsize=30)
b.set_ylabel("high-cost ratio",fontsize=12)
b.tick_params(labelsize=12)

# %%
# Order labels
sortedLabels = np.argsort( highcostratio ).tolist()
Labels2 = np.zeros( Labels.shape)-1
index = 0

for sortedNumber in sortedLabels:
    inNumber = np.where( Labels == sortedNumber)[0]
    Labels2[inNumber] = index
    index += 1
Labels = Labels2

# %%
# #plot highcost ratio among cadres
# from highcostratio import highcostplot
# target,Labels,highcostratio,remove_index = highcostplot(d_newborn_tr,d_newborn_te, newborn_best)
# # the log odds ratios of being highcost in different clusters
from ftest_logodds import restest

restest(np.expand_dims(Labels,axis=1),
        np.expand_dims(target['Target'],axis=1)).round(2)

# %%
# Calculate log odds ratios for feature vs. cluster, uncorr
from ftest_logodds import ftest_uncorr

features = list(d_newborn_tr.iloc[:,:-1])
data = np.append(d_newborn_tr.iloc[:,:-1],d_newborn_te.iloc[:,:-1],axis=0)
np_feat = np.asarray(features)
labs = np.expand_dims(Labels,axis=1)
feat_table,lor_table =ftest_uncorr(data,labs,np_feat)

# %%
# reduce feature length
new_feat = [s.replace('CCS.DX_' , '') for s in features]
new_feat = [s.replace('CCS.PROC_' , '') for s in new_feat]
new_feat = [s.replace(' not mental disorders or infectious disease','')for s in new_feat]
new_feat = [s.replace('birth weight; and','BW&')for s in new_feat]
new_feat = [s.replace('sexually transmitted disease','STD')for s in new_feat]
new_feat = [s.replace('tuberculosis','TB')for s in new_feat]
new_feat = [s.replace('system','syst')for s in new_feat]
new_feat = [s.replace('Other','Ot')for s in new_feat]
new_feat = [s.replace('OTHER','Ot')for s in new_feat]

# %%
# clustermaps of segments of features.
# Red indicates a given feature has significant positive log ordds ratio to a given cluster, 
# light purple no significance, blue significant negative.
from clustmap import plotclustmap

sns.set(font_scale=1.1)
# racial features
plotclustmap(feat_table[:,11:19].T,None,np.array(new_feat)[11:19],None,None)
plt.yticks(rotation=0) 
# county features
plotclustmap(feat_table[:,3:8].T,None,np.array(new_feat)[3:8],None,None)
plt.yticks(rotation=0)

# # # admission features
plotclustmap(feat_table[:,19:23].T,None,np.array(new_feat)[19:23],None,None)
plt.yticks(rotation=0)

# ER, Low BW, Inflow
plotclustmap(feat_table[:,0:3].T,None,np.array(new_feat)[0:3],None,None)
plt.yticks(rotation=0)

# # #disease features
plotclustmap(feat_table[:,23:72].T,None,np.array(new_feat)[23:72],None,None)
# # # procedure features
plotclustmap(feat_table[:,72:116].T,None,np.array(new_feat)[72:116],None,None)
plotclustmap(feat_table[:,116:].T,None,np.array(new_feat)[116:],None,None)

# %%
weights = np.array(model.weights)
weights.shape

# %%
# plot the weights
N = weights.shape[0]
from clustmap import plotclustmap
plotclustmap(weights.T[abs(weights.T).sum(axis = 1)/N > 1],None, np.array(new_feat)[abs(weights.T).sum(axis = 1)/N > 1], None, None)

# %%
# create a binary version of the weights: red, weight>0, blue , weight <0
bin_weights = (newborn_best.W[abs(newborn_best.W.T).sum()>1e-1]>0)*1 + (newborn_best.W[abs(newborn_best.W.T).sum()>1e-1]<0)*(-1) 
plotclustmap(bin_weights,None,np.array(new_feat)[abs(newborn_best.W.T).sum()>1e-1],None,None)
